// %%
@file:Repository("*mavenLocal")
@file:DependsOn("ru.mipt.npm:jupyter-mpp-demo-jvm:1.0-SNAPSHOT")
// Out:
//             <div id="kotlin_out_0"/>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["jupyter-mpp"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["jupyter-mpp"] = resQueue;
//                 window["call_jupyter-mpp"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
// ...

// %%
val widget = TextWidget("fff")
widget
// Out:
// <div class="kotlin-widget" id="kotlin-widget-0" data-widget-id="TextWidget@56a1e0b4" data-widget-type="textField">
//   <script type="text/json" class="kotlin-widget-data">"fff"</script>
//   <script type="text/javascript">renderWidget("kotlin-widget-0");</script>
// </div>

// %%
widget.text = "abcd"

// %%
widget.text
// Out:
// abcd

// %%
val checkBox = CheckBox(true)
checkBox
// Out:
// <div class="kotlin-widget" id="kotlin-widget-2" data-widget-id="CheckBox@412a84f1" data-widget-type="checkBox">
//   <script type="text/json" class="kotlin-widget-data">true</script>
//   <script type="text/javascript">renderWidget("kotlin-widget-2");</script>
// </div>

// %%
checkBox.checked
// Out:
// false
